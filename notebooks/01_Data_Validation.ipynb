# %%
# Step 1: Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
# Step 2: Load dataset

file_path = "European_Bank.csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
df.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.tail()
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0

# %%
# Step 3: Check number of rows and columns

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 10000
# Number of columns: 14

# %%
# Step 4: Display column names

print(df.columns.tolist())
# Out:
# ['Year', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %%
# Step 5: Check data types and non-null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Step 6: Check missing values

missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Step 7: Check complete duplicate rows

duplicate_rows = df.duplicated().sum()

print("Duplicate rows:", duplicate_rows)
# Out:
# Duplicate rows: 0

# %%
# Step 8: Check duplicate Customer IDs

duplicate_customer_ids = df["CustomerId"].duplicated().sum()

print("Duplicate Customer IDs:", duplicate_customer_ids)
# Out:
# Duplicate Customer IDs: 0

# %%
# Step 9: Check categorical values

print("Geography:")
print(df["Geography"].unique())

print("\nGender:")
print(df["Gender"].unique())

print("\nHasCrCard:")
print(df["HasCrCard"].unique())

print("\nIsActiveMember:")
print(df["IsActiveMember"].unique())

print("\nExited:")
print(df["Exited"].unique())
# Out:
# Geography:
# ['France' 'Spain' 'Germany']
#
# Gender:
# ['Female' 'Male']
#
# HasCrCard:
# [1 0]
#
# IsActiveMember:
# [1 0]
#
# Exited:
# [1 0]

# %%
# Step 10: Geography distribution

print(df["Geography"].value_counts())
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Step 11: Check numerical ranges

numeric_columns = [
    "CreditScore",
    "Age",
    "Tenure",
    "Balance",
    "NumOfProducts",
    "EstimatedSalary"
]

for col in numeric_columns:
    print(f"\n{col}")
    print("Minimum:", df[col].min())
    print("Maximum:", df[col].max())
# Out:
# CreditScore
# Minimum: 350
# Maximum: 850
#
# Age
# Minimum: 18
# Maximum: 92
#
# Tenure
# Minimum: 0
# Maximum: 10
#
# Balance
# Minimum: 0.0
# Maximum: 250898.09
#
# NumOfProducts
# Minimum: 1
# Maximum: 4
#
# EstimatedSalary
# Minimum: 11.58
# Maximum: 199992.48

# %%
# Step 12: Validate binary variables

binary_columns = [
    "HasCrCard",
    "IsActiveMember",
    "Exited"
]

for col in binary_columns:
    unique_values = sorted(df[col].dropna().unique())
    
    print(f"{col}: {unique_values}")
    
    if set(unique_values).issubset({0, 1}):
        print("Status: VALID")
    else:
        print("Status: CHECK REQUIRED")
# Out:
# HasCrCard: [np.int64(0), np.int64(1)]
# Status: VALID
# IsActiveMember: [np.int64(0), np.int64(1)]
# Status: VALID
# Exited: [np.int64(0), np.int64(1)]
# Status: VALID

# %%
# Step 13: Target variable distribution

print(df["Exited"].value_counts())
print("\nChurn percentage:")
print(df["Exited"].value_counts(normalize=True) * 100)
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
#
# Churn percentage:
# Exited
# 0    79.63
# 1    20.37
# Name: proportion, dtype: float64

# %%
# Step 14: Create validation summary

validation_summary = {
    "Rows": len(df),
    "Columns": len(df.columns),
    "Missing Values": int(df.isnull().sum().sum()),
    "Duplicate Rows": int(df.duplicated().sum()),
    "Duplicate Customer IDs": int(df["CustomerId"].duplicated().sum()),
    "Churn Rate": round(df["Exited"].mean() * 100, 2)
}

validation_summary
# Out:
# {'Rows': 10000,
#  'Columns': 14,
#  'Missing Values': 0,
#  'Duplicate Rows': 0,
#  'Duplicate Customer IDs': 0,
#  'Churn Rate': np.float64(20.37)}

# %%
# Step 15: Final validation check

assert df.shape == (10000, 14), "Unexpected dataset dimensions"
assert df.isnull().sum().sum() == 0, "Missing values found"
assert df.duplicated().sum() == 0, "Duplicate rows found"
assert df["CustomerId"].duplicated().sum() == 0, "Duplicate Customer IDs found"
assert set(df["HasCrCard"].unique()).issubset({0, 1}), "Invalid HasCrCard values"
assert set(df["IsActiveMember"].unique()).issubset({0, 1}), "Invalid IsActiveMember values"
assert set(df["Exited"].unique()).issubset({0, 1}), "Invalid Exited values"

print("✅ DATA VALIDATION PASSED")
# Out:
# ✅ DATA VALIDATION PASSED

# %%
df_clean["Engagement_Profile"].value_counts()
# Out:
# Engagement_Profile
# Active Engaged            2588
# Active Low-Product        2563
# Inactive Disengaged       2521
# Inactive Multi-Product    2328
# Name: count, dtype: int64

# %%
balance_threshold = df_clean["Balance"].quantile(0.75)

print("High balance threshold:", balance_threshold)
# Out:
# High balance threshold: 127644.24

# %%
df_clean["High_Value_Customer"] = np.where(
    df_clean["Balance"] >= balance_threshold,
    1,
    0
)

# %%
df_clean["High_Value_Customer"].value_counts()
# Out:
# High_Value_Customer
# 0    7500
# 1    2500
# Name: count, dtype: int64

# %%
df_clean["High_Value_Disengaged"] = np.where(
    (df_clean["High_Value_Customer"] == 1) &
    (df_clean["IsActiveMember"] == 0),
    1,
    0
)
df_clean["High_Value_Disengaged"].value_counts()
# Out:
# High_Value_Disengaged
# 0    8753
# 1    1247
# Name: count, dtype: int64

# %%
def customer_value_segment(row):
    
    if row["High_Value_Customer"] == 1 and row["IsActiveMember"] == 1:
        return "High Value - Engaged"
    
    elif row["High_Value_Customer"] == 1 and row["IsActiveMember"] == 0:
        return "High Value - Disengaged"
    
    elif row["High_Value_Customer"] == 0 and row["IsActiveMember"] == 1:
        return "Standard Value - Engaged"
    
    else:
        return "Standard Value - Disengaged"

df_clean["Customer_Value_Segment"] = df_clean.apply(
    customer_value_segment,
    axis=1
)
df_clean["Customer_Value_Segment"].value_counts()
# Out:
# Customer_Value_Segment
# Standard Value - Engaged       3898
# Standard Value - Disengaged    3602
# High Value - Engaged           1253
# High Value - Disengaged        1247
# Name: count, dtype: int64

# %%
df_clean["Credit_Card_Status"] = np.where(
    df_clean["HasCrCard"] == 1,
    "Card Holder",
    "Non Card Holder"
)

# %%
df_clean["Engagement_Score"] = (
    df_clean["IsActiveMember"] * 50
    + np.where(df_clean["NumOfProducts"] >= 2, 30, 0)
    + df_clean["HasCrCard"] * 20
)

# %%
df_clean["Engagement_Score"].value_counts().sort_index()
# Out:
# Engagement_Score
# 0       718
# 20     1803
# 30      683
# 50     2433
# 70     1775
# 80      756
# 100    1832
# Name: count, dtype: int64

# %%
def retention_risk(row):
    
    if row["High_Value_Disengaged"] == 1:
        return "High Risk"
    
    elif row["IsActiveMember"] == 0 and row["NumOfProducts"] == 1:
        return "High Risk"
    
    elif row["IsActiveMember"] == 0:
        return "Medium Risk"
    
    else:
        return "Low Risk"

df_clean["Initial_Retention_Risk"] = df_clean.apply(
    retention_risk,
    axis=1
)
df_clean["Initial_Retention_Risk"].value_counts()
# Out:
# Initial_Retention_Risk
# Low Risk       5151
# High Risk      2940
# Medium Risk    1909
# Name: count, dtype: int64

# %%
df_clean["Balance_to_Salary_Ratio"] = (
    df_clean["Balance"] /
    df_clean["EstimatedSalary"].replace(0, np.nan)
)
df_clean["Balance_to_Salary_Ratio"].describe()
# Out:
# count    10000.000000
# mean         3.878703
# std        108.337260
# min          0.000000
# 25%          0.000000
# 50%          0.747002
# 75%          1.514022
# max      10614.655440
# Name: Balance_to_Salary_Ratio, dtype: float64

# %%
balance_median = df_clean["Balance"].median()
salary_median = df_clean["EstimatedSalary"].median()

def financial_segment(row):
    
    if row["Balance"] >= balance_median and row["EstimatedSalary"] >= salary_median:
        return "High Salary - High Balance"
    
    elif row["Balance"] >= balance_median and row["EstimatedSalary"] < salary_median:
        return "Low Salary - High Balance"
    
    elif row["Balance"] < balance_median and row["EstimatedSalary"] >= salary_median:
        return "High Salary - Low Balance"
    
    else:
        return "Low Salary - Low Balance"

df_clean["Financial_Segment"] = df_clean.apply(
    financial_segment,
    axis=1
)

# %%
df_clean["Churn_Status"] = np.where(
    df_clean["Exited"] == 1,
    "Churned",
    "Retained"
)

# %%
new_columns = [
    "Age_Group",
    "Balance_Segment",
    "Salary_Segment",
    "Product_Depth_Group",
    "Engagement_Status",
    "Engagement_Profile",
    "High_Value_Customer",
    "High_Value_Disengaged",
    "Customer_Value_Segment",
    "Credit_Card_Status",
    "Engagement_Score",
    "Initial_Retention_Risk",
    "Balance_to_Salary_Ratio",
    "Financial_Segment",
    "Churn_Status"
]

df_clean[new_columns].head(10)
# Out:
#   Age_Group    Balance_Segment    Salary_Segment Product_Depth_Group  \
# 0     36-45        Low Balance       High Salary      Single Product
# 1     36-45     Medium Balance       High Salary      Single Product
# 2     36-45  Very High Balance       High Salary         3+ Products
# 3     36-45        Low Balance     Medium Salary        Two Products
# 4     36-45       High Balance     Medium Salary      Single Product
# 5     36-45       High Balance  Very High Salary        Two Products
# 6     46-55        Low Balance        Low Salary        Two Products
# 7     26-35       High Balance       High Salary         3+ Products
# 8     36-45  Very High Balance     Medium Salary        Two Products
# 9     26-35  Very High Balance     Medium Salary      Single Product
#
#   Engagement_Status      Engagement_Profile  High_Value_Customer  \
# 0            Active      Active Low-Product                    0
# 1            Active      Active Low-Product                    0
# 2          Inactive  Inactive Multi-Product                    1
# 3          Inactive  Inactive Multi-Product                    0
# 4            Active      Active Low-Product                    0
# 5          Inactive  Inactive Multi-Product                    0
# 6            Active          Active Engaged                    0
# 7          Inactive  Inactive Multi-Product                    0
# 8            Active          Active Engaged                    1
# 9            Active      Active Low-Product                    1
#
#    High_Value_Disengaged       Customer_Value_Segment Credit_Card_Status  \
# 0                      0     Standard Value - Engaged        Card Holder
# 1                      0     Standard Value - Engaged    Non Card Holder
# 2                      1      High Value - Disengaged        Card Holder
# 3                      0  Standard Value - Disengaged    Non Card Holder
# 4                      0     Standard Value - Engaged        Card Holder
# 5                      0  Standard Value - Disengaged        Card Holder
# 6                      0     Standard Value - Engaged        Card Holder
# 7                      0  Standard Value - Disengaged        Card Holder
# 8                      0         High Value - Engaged    Non Card Holder
# 9                      0         High Value - Engaged        Card Holder
#
#    Engagement_Score Initial_Retention_Risk  Balance_to_Salary_Ratio  \
# 0                70               Low Risk                 0.000000
# 1                50               Low Risk                 0.744677
# 2                50              High Risk                 1.401375
# 3                30            Medium Risk                 0.000000
# 4                70               Low Risk                 1.587055
# 5                50            Medium Risk                 0.759604
# 6               100               Low Risk                 0.000000
# 7                50            Medium Risk                 0.963969
# 8                80               Low Risk                 1.895518
# 9                70               Low Risk                 1.876647
#
#             Financial_Segment Churn_Status
# 0   High Salary - Low Balance      Churned
# 1   High Salary - Low Balance     Retained
# 2  High Salary - High Balance      Churned
# 3    Low Salary - Low Balance     Retained
# 4   Low Salary - High Balance     Retained
# 5  High Salary - High Balance      Churned
# 6    Low Salary - Low Balance     Retained
# 7  High Salary - High Balance      Churned
# 8   Low Salary - High Balance     Retained
# 9   Low Salary - High Balance     Retained

# %%
print("Original columns:", len(df.columns))
print("New columns:", len(df_clean.columns))

df_clean.info()
# Out:
# Original columns: 14
# New columns: 29
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10000 non-null  int64
#  1   CustomerId               10000 non-null  int64
#  2   Surname                  10000 non-null  object
#  3   CreditScore              10000 non-null  int64
#  4   Geography                10000 non-null  object
#  5   Gender                   10000 non-null  object
#  6   Age                      10000 non-null  int64
#  7   Tenure                   10000 non-null  int64
#  8   Balance                  10000 non-null  float64
#  9   NumOfProducts            10000 non-null  int64
#  10  HasCrCard                10000 non-null  int64
#  11  IsActiveMember           10000 non-null  int64
#  12  EstimatedSalary          10000 non-null  float64
#  13  Exited                   10000 non-null  int64
#  14  Age_Group                10000 non-null  category
#  15  Balance_Segment          10000 non-null  category
#  16  Salary_Segment           10000 non-null  category
#  17  Product_Depth_Group      10000 non-null  object
#  18  Engagement_Status        10000 non-null  object
#  19  Engagement_Profile       10000 non-null  object
#  20  High_Value_Customer      10000 non-null  int64
#  21  High_Value_Disengaged    10000 non-null  int64
#  22  Customer_Value_Segment   10000 non-null  object
#  23  Credit_Card_Status       10000 non-null  object
#  24  Engagement_Score         10000 non-null  int64
#  25  Initial_Retention_Risk   10000 non-null  object
#  26  Balance_to_Salary_Ratio  10000 non-null  float64
#  27  Financial_Segment        10000 non-null  object
#  28  Churn_Status             10000 non-null  object
# dtypes: category(3), float64(3), int64(12), object(11)
# memory usage: 2.0+ MB

# %%
# Check missing values in engineered features

engineered_columns = new_columns

print(
    df_clean[engineered_columns]
    .isnull()
    .sum()
)
# Out:
# Age_Group                  0
# Balance_Segment            0
# Salary_Segment             0
# Product_Depth_Group        0
# Engagement_Status          0
# Engagement_Profile         0
# High_Value_Customer        0
# High_Value_Disengaged      0
# Customer_Value_Segment     0
# Credit_Card_Status         0
# Engagement_Score           0
# Initial_Retention_Risk     0
# Balance_to_Salary_Ratio    0
# Financial_Segment          0
# Churn_Status               0
# dtype: int64

# %%
# Check duplicate customers again

print("Duplicate Customer IDs:",
      df_clean["CustomerId"].duplicated().sum())
# Out:
# Duplicate Customer IDs: 0

# %%
# Check churn values

print("Churn values:",
      df_clean["Exited"].unique())
# Out:
# Churn values: [1 0]

# %%
output_file = "European_Bank_Cleaned_Featured.csv"

df_clean.to_csv(
    output_file,
    index=False
)

print(f"✅ Cleaned dataset saved as: {output_file}")
# Out:
# ✅ Cleaned dataset saved as: European_Bank_Cleaned_Featured.csv
